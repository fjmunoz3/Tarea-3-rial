# %%
import sqlite3, csv

connection = sqlite3.connect('musica1.db')

cursor = connection.cursor()

cursor.execute("DROP TABLE genres")
cursor.execute("CREATE TABLE genres(id INTEGER, Artist TEXT, Genre TEXT)")

with open('genres.csv', newline='', encoding='utf-8') as csvfile:
    datareader = csv.reader(csvfile, delimiter='\t', quotechar='|')
    
    i=0
    for row in datareader:
        row = row[0].split(",")
        aux = (i, row[0], row[1])
        
        cursor.execute("INSERT INTO genres VALUES(?,?,?)", aux)
        i += 1

            
#Eliminaremos la primera fila (encabezados)
primera_fila=(0,)            
cursor.execute('DELETE FROM genres WHERE id=?', primera_fila)

cursor.execute('SELECT * FROM genres')  #Lo comenté porque no quiero ver el output, de momento
print(cursor.fetchall())

connection.commit()
connection.close()

#NEXT:

# connection = sqlite3.connect('musica1.db')

# cursor = connection.cursor()

# cursor.execute("DROP TABLE tracks")
# cursor.execute("CREATE TABLE genres(id INTEGER, MODIFICAR ESTO)")
#SEGUIR DE MANERA ANÁLOGA A LO QUE ESTÁ ARRIBA
# Out:
# [(1, 'Eurythmics', '80s'), (2, 'Eurythmics', 'New wave'), (3, 'Eurythmics', 'Pop'), (4, 'Eurythmics', 'Female vocalists'), (5, 'Eurythmics', 'Synth pop'), (6, 'Camila Cabello', 'Pop'), (7, 'Camila Cabello', 'Female vocalists'), (8, 'Camila Cabello', 'Dance'), (9, 'Camila Cabello', 'Cuba'), (10, 'Camila Cabello', 'Fifth harmony'), (11, 'Fármacos', 'Indie'), (12, 'Fármacos', 'Indie pop'), (13, 'Fármacos', 'Post folk'), (14, 'Fármacos', 'Chilean'), (15, 'Fármacos', 'Pop'), (16, 'Miranda!', 'Pop'), (17, 'Miranda!', 'Electropop'), (18, 'Miranda!', 'Argentina'), (19, 'Miranda!', 'Electronic'), (20, 'Miranda!', 'Dance'), (21, 'Robyn', 'Pop'), (22, 'Robyn', 'Electronic'), (23, 'Robyn', 'Swedish'), (24, 'Robyn', 'Female vocalists'), (25, 'Robyn', 'Seen live'), (26, 'Dua Lipa', 'Pop'), (27, 'Dua Lipa', 'Female vocalists'), (28, 'Dua Lipa', 'British'), (29, 'Dua Lipa', 'Synthpop'), (30, 'Dua Lipa', 'Electropop'), (31, 'Britney Spears', 'Pop'), (32, 'Britney Spears', 'Dance'), (33, 'Britney Spears', 'Female vocalists'), (34, 'Britney Spears', 'Britney spears'), (35, 'Britney Spears', 'Legend'), (36, 'Panic! at the Disco', 'Rock'), (37, 'Panic! at the Disco', 'Alternative'), (38, 'Panic! at the Disco', 'Emo'), (39, 'Panic! at the Disco', 'Pop punk'), (40, 'Panic! at the Disco', 'Indie'), (41, 'Death Cab for Cutie', 'Indie'), (42, 'Death Cab for Cutie', 'Indie rock'), (43, 'Death Cab for Cutie', 'Alternative'), (44, 'Death Cab for Cutie', 'Seen live'), (45, 'Death Cab for Cutie', 'Rock'), (46, 'Phoenix', 'Indie'), (47, 'Phoenix', 'French'), (48, 'Phoenix', 'Indie pop'), (49, 'Pho